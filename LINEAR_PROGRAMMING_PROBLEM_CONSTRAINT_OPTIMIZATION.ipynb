# %% [markdown]
# <a href="https://colab.research.google.com/github/sri2-star/Optimization-techniques-for-AI/blob/main/LINEAR_PROGRAMMING_PROBLEM_CONSTRAINT_OPTIMIZATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.optimize import linprog
c = [-3, -2]
A = [
[2, 1],
[4, -5]
]
b = [20, 10]
x_bounds = (0, None)
y_bounds = (0, None)
result = linprog(c, A_ub=A, b_ub=b, bounds=[x_bounds, y_bounds],
method='highs')
print('Optimal value:', -result.fun)
print('Values of x:', result.x)
# Out:
# Optimal value: 40.0
# Values of x: [ 0. 20.]
